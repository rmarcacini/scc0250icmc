# %% [markdown]
# # Aula02.Ex05 - Malhas
#
# Na Aula 02, nivelamento de conceitos de computação gráfica, nós discutimos sobre triangulação e malhas.
#
# Vamos ver alguns exemplos?

# %% [markdown]
# ## Primeiro vamos instalar alguns pacotes!
# OBS: esses pacotes tem a única finalidade de demonstração visual. Não devem ser usados ao longo da disciplina para desenvolvimento dos trabalhos.

# %%
import io
import zipfile
import urllib.request as urllib
from zipfile import ZipFile
import importlib
import requests 
# !pip install vispy 
# !pip install pyvista

url = "https://github.com/rmarcacini/scc0250icmc/archive/master.zip"
with open('master.zip', 'wb') as f:
    resp = requests.get(url, verify=False)
    f.write(resp.content)

with ZipFile('master.zip', 'r') as zipObj:
    # Extract all the contents of zip file in different directory
    zipObj.extractall('dscc0250')

# %% [markdown]
# ### Vamos ver a triagulação em "terreno" formado a partir de uma gaussiana.

# %%
# %matplotlib inline
mod = importlib.import_module("dscc0250.scc0250icmc-master.aula02.exemplos_vispy_triangulacao")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F0B8AB775F8>
# 2020-02-27 15:49:02,283 [7676] ERROR    root:51: [JupyterRequire] The interactor must be set prior to enabling/disabling widget
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F0B88F67C50>
# 2020-02-27 15:49:02,451 [7676] ERROR    root:51: [JupyterRequire] The interactor must be set prior to enabling/disabling widget
